# %% [markdown]
# <a href="https://colab.research.google.com/github/liscandeia/Codelab_Data/blob/main/ENEM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORT
import pandas as pd

# %%
#Configurando display de saide da tabela
pd.set_option('display.max_columns', None)

#Escolhendo colunas no arquivo dicionario de dados
#024,025, 022 verificar relação do internet e nota
#001,002 verificar relação de pais com maior nivel de graduação e nota
#006 verificar relação de situação financeira e nota
colunas = [
    'NU_ANO',
    'TP_FAIXA_ETARIA',
    'TP_SEXO',
    'TP_COR_RACA',
    'TP_ST_CONCLUSAO',
    'TP_ESCOLA',
    'TP_DEPENDENCIA_ADM_ESC',
    'TP_LOCALIZACAO_ESC',
    'CO_MUNICIPIO_ESC',
    'NU_NOTA_REDACAO',
    'NU_NOTA_LC',
    'NU_NOTA_MT',
    'NU_NOTA_CN',
    'NU_NOTA_CH',
    'Q001',
    'Q002',
    'Q006',
    'Q022',
    'Q024',
    'Q025']

enem_2021_df = pd.read_csv('/content/MICRODADOS_ENEM_2021.csv', sep=";",encoding='ISO-8859-1', usecols=colunas)
enem_2021_df.shape
# Out:
#         NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0       210053865474    2021                5       F                1
# 1       210052384164    2021               12       M                1
# 2       210052589243    2021               13       F                3
# 3       210052128335    2021                3       M                1
# 4       210051353021    2021                2       F                1
# ...              ...     ...              ...     ...              ...
# 120698  210052814880    2021                2       F                1
# 120699  210052176701    2021                5       M                1
# 120700  210053002651    2021               11       F                2
# 120701  210053676292    2021                6       F                1
# 120702  210053330747    2021                2       M                1
#
#         TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# ...

# %%
enem_2021_df.head()
# Out:
#    NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_COR_RACA  TP_ST_CONCLUSAO  TP_ESCOLA  \
# 0    2021                5       F            1                1          1
# 1    2021               12       M            1                1          1
# 2    2021               13       F            1                1          1
# 3    2021                3       M            3                2          2
# 4    2021                2       F            3                2          2
#
#    CO_MUNICIPIO_ESC  TP_DEPENDENCIA_ADM_ESC  TP_LOCALIZACAO_ESC  NU_NOTA_CN  \
# 0               NaN                     NaN                 NaN         NaN
# 1               NaN                     NaN                 NaN       505.9
# 2               NaN                     NaN                 NaN         NaN
# 3         2304202.0                     2.0                 1.0       580.7
# 4         2311603.0                     2.0                 1.0       497.7
#
# ...

# %%
# isna
print(enem_2021_df.isna().sum())

# isnull
print(enem_2021_df.isnull().sum())
# Out:
# NU_ANO                       0
# TP_FAIXA_ETARIA              0
# TP_SEXO                      0
# TP_COR_RACA                  0
# TP_ST_CONCLUSAO              0
# TP_ESCOLA                    0
# CO_MUNICIPIO_ESC          9879
# TP_DEPENDENCIA_ADM_ESC    9879
# TP_LOCALIZACAO_ESC        9879
# NU_NOTA_CN                2824
# NU_NOTA_CH                2406
# NU_NOTA_LC                2406
# NU_NOTA_MT                2824
# NU_NOTA_REDACAO           2407
# Q001                         1
# Q002                         1
# Q006                         1
# Q022                         1
# Q024                         1
# Q025                         1
# dtype: int64
# NU_ANO                       0
# TP_FAIXA_ETARIA              0
# TP_SEXO                      0
# TP_COR_RACA                  0
# TP_ST_CONCLUSAO              0
# TP_ESCOLA                    0
# CO_MUNICIPIO_ESC          9879
# TP_DEPENDENCIA_ADM_ESC    9879
# TP_LOCALIZACAO_ESC        9879
# ...

# %%
#Tratamento dos dados
#Excluindo os nulos em qualquer uma das provas pra não afetar a analise
enem_2021_df.dropna(subset=['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO'], inplace=True)
enem_2021_df.head()
enem_2021_df.shape
#Excluindo os nulos de q001...q0025 pois é só uma linha e não vai afetar no banco
enem_2021_df.dropna(subset=['Q001','Q002','Q006', 'Q022', 'Q024', 'Q025'], inplace=True)
enem_2021_df.shape
print(enem_2021_df.isna().sum())
print(enem_2021_df.isnull().sum())
# Out:
# (9935, 20)

# %%
#Excluindo os nulos de q001...q0025 pois é só uma linha e não vai afetar no banco
enem_2021_df.dropna(subset=['Q001','Q002','Q006', 'Q022', 'Q024', 'Q025'], inplace=True)
enem_2021_df.shape
# Out:
# (9935, 20)

# %%
# verificando
print(enem_2021_df.isna().sum())
print(enem_2021_df.isnull().sum())
# Out:
# NU_ANO                       0
# TP_FAIXA_ETARIA              0
# TP_SEXO                      0
# TP_COR_RACA                  0
# TP_ST_CONCLUSAO              0
# TP_ESCOLA                    0
# CO_MUNICIPIO_ESC          7416
# TP_DEPENDENCIA_ADM_ESC    7416
# TP_LOCALIZACAO_ESC        7416
# NU_NOTA_CN                   0
# NU_NOTA_CH                   0
# NU_NOTA_LC                   0
# NU_NOTA_MT                   0
# NU_NOTA_REDACAO              0
# Q001                         0
# Q002                         0
# Q006                         0
# Q022                         0
# Q024                         0
# Q025                         0
# dtype: int64
# NU_ANO                       0
# TP_FAIXA_ETARIA              0
# TP_SEXO                      0
# TP_COR_RACA                  0
# TP_ST_CONCLUSAO              0
# TP_ESCOLA                    0
# CO_MUNICIPIO_ESC          7416
# TP_DEPENDENCIA_ADM_ESC    7416
# TP_LOCALIZACAO_ESC        7416
# ...

# %%
#Transformando para leitura
enem_2021_df['TP_FAIXA_ETARIA'] = enem_2021_df['TP_FAIXA_ETARIA'].map({
    1: 'Menor que 17 anos',
    2: '17 anos',
    3: '18 anos',
    4: '19 anos',
    5: '20 anos',
    6: '21 anos',
    7: '22 anos',
    8: '23 anos',
    9: '24 anos',
    10: '25 anos',
    11: 'entre 26 e 30 anos',
    12: 'entre 31 e 35 anos',
    13: 'entre 36 e 40 anos',
    14: 'entre 41 e 45 anos',
    15: 'entre 46 e 50 anos',
    16: 'entre 51 e 55 anos',
    17: 'entre 56 e 60 anos',
    18: 'entre 61 e 65 anos',
    19: 'entre 66 e 70 anos',
    20: 'mais de 70 anos'

})

enem_2021_df.head()
# Out:
#    NU_ANO     TP_FAIXA_ETARIA TP_SEXO  TP_COR_RACA  TP_ST_CONCLUSAO  \
# 1    2021  entre 31 e 35 anos       M            1                1
# 3    2021             18 anos       M            3                2
# 4    2021             17 anos       F            3                2
# 8    2021             23 anos       F            3                2
# 9    2021             19 anos       F            3                2
#
#    TP_ESCOLA  CO_MUNICIPIO_ESC  TP_DEPENDENCIA_ADM_ESC  TP_LOCALIZACAO_ESC  \
# 1          1               NaN                     NaN                 NaN
# 3          2         2304202.0                     2.0                 1.0
# 4          2         2311603.0                     2.0                 1.0
# 8          2               NaN                     NaN                 NaN
# 9          2               NaN                     NaN                 NaN
#
#    NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002  \
# ...

# %%
mapa_regioes = {
    '1': 'Norte',
    '2': 'Nordeste',
    '3': 'Sudeste',
    '4': 'Sul',
    '5': 'Centro-Oeste'
}
mapa_uf = {
    '11': 'Rondônia',
    '12': 'Acre',
    '13': 'Amazonas',
    '14': 'Roraima',
    '15': 'Pará',
    '16': 'Amapá',
    '17': 'Tocantins',
    '21': 'Maranhão',
    '22': 'Piauí',
    '23': 'Ceará',
    '24': 'Rio Grande do Norte',
    '25': 'Paraíba',
    '26': 'Pernambuco',
    '27': 'Alagoas',
    '28': 'Sergipe',
    '29': 'Bahia',
    '31': 'Minas Gerais',
    '32': 'Espírito Santo',
    '33': 'Rio de Janeiro',
    '35': 'São Paulo',
    '41': 'Paraná',
    '42': 'Santa Catarina',
    '43': 'Rio Grande do Sul',
    '50': 'Mato Grosso do Sul',
    '51': 'Mato Grosso',
    '52': 'Goiás',
    '53': 'Distrito Federal'
}

enem_2021_df['CO_REGIAO_ESC'] = enem_2021_df['CO_MUNICIPIO_ESC'].astype(str).apply(lambda codigo_municipio : codigo_municipio[0])
enem_2021_df['CO_REGIAO_ESC'] = enem_2021_df['CO_REGIAO_ESC'].map(mapa_regioes)
enem_2021_df.head()
enem_2021_df['CO_UF_ESC'] = enem_2021_df['CO_MUNICIPIO_ESC'].astype(str).apply(lambda codigo_municipio : codigo_municipio[:2])
enem_2021_df['CO_UF_ESC'] = enem_2021_df['CO_UF_ESC'].map(mapa_uf)
enem_2021_df.head()
# Out:
#    NU_ANO     TP_FAIXA_ETARIA TP_SEXO  TP_COR_RACA  TP_ST_CONCLUSAO  \
# 1    2021  entre 31 e 35 anos       M            1                1
# 3    2021             18 anos       M            3                2
# 4    2021             17 anos       F            3                2
# 8    2021             23 anos       F            3                2
# 9    2021             19 anos       F            3                2
#
#    TP_ESCOLA  CO_MUNICIPIO_ESC  TP_DEPENDENCIA_ADM_ESC  TP_LOCALIZACAO_ESC  \
# 1          1               NaN                     NaN                 NaN
# 3          2         2304202.0                     2.0                 1.0
# 4          2         2311603.0                     2.0                 1.0
# 8          2               NaN                     NaN                 NaN
# 9          2               NaN                     NaN                 NaN
#
#    NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002  \
# ...

# %%
enem_2021_df['TP_COR_RACA'] = enem_2021_df['TP_COR_RACA'].map({0:'NA', 1:'Branca', 2:'Preta', 3:'Parda', 4:'Amarela', 5:'Indigena'})

# %%
enem_2021_df['Q025'] = enem_2021_df['Q025'].map({'A':'Não', 'B':'Sim'})

# %%
enem_2021_df['Q001'] = enem_2021_df['Q001'].map({
                            'A':'Nunca estudou',
                            'B':'Não completou EF',
                            'C':'Não completou EF',
                            'D':'Não completou EM',
                            'E':'Não completou ES',
                            'F':'Graduada',
                            'G':'Pós-graduada',
                            'H':'Não sabe'
                            })
enem_2021_df['Q002'] = enem_2021_df['Q002'].map({
                            'A':'Nunca estudou',
                            'B':'Não completou EF',
                            'C':'Não completou EF',
                            'D':'Não completou EM',
                            'E':'Não completou ES',
                            'F':'Graduada',
                            'G':'Pós-graduada',
                            'H':'Não sabe'
                            })

# %%
enem_2021_df['Q006'] = enem_2021_df['Q006'].map({'A':'Nenhuma renda',
                            'B':'Até 1.045,00',
                            'C':'Até 1.567,50',
                            'D':'Até 2.090,00',
                            'E':'Até 2.612,50',
                            'F':'Até 3.135,00',
                            'G':'Até 4.180,00',
                            'H':'Até 5.225,00',
                            'I':'Até 6.270,00',
                            'J':'Até 7.315,00',
                            'K':'Até 8.360,00',
                            'L':'Até 9.405,00',
                            'M':'Até 10.450,00',
                            'N':'Até 12.540,00',
                            'O':'Até 15.675,00',
                            'P':'Até 20.900,00',
                            'Q':'Acima de 20.900,00'
                            })

# %%
enem_2021_df.head()
# Out:
#    NU_ANO     TP_FAIXA_ETARIA TP_SEXO TP_COR_RACA  TP_ST_CONCLUSAO  TP_ESCOLA  \
# 1    2021  entre 31 e 35 anos       M      Branca                1          1
# 3    2021             18 anos       M       Parda                2          2
# 4    2021             17 anos       F       Parda                2          2
# 8    2021             23 anos       F       Parda                2          2
# 9    2021             19 anos       F       Parda                2          2
#
#    CO_MUNICIPIO_ESC  TP_DEPENDENCIA_ADM_ESC  TP_LOCALIZACAO_ESC  NU_NOTA_CN  \
# 1               NaN                     NaN                 NaN       505.9
# 3         2304202.0                     2.0                 1.0       580.7
# 4         2311603.0                     2.0                 1.0       497.7
# 8               NaN                     NaN                 NaN       487.4
# 9               NaN                     NaN                 NaN       507.6
#
# ...

# %%
enem_2021_df['TP_ESCOLA'] = enem_2021_df['TP_ESCOLA'].map({
    1: 'Não Respondeu',
    2: 'Pública',
    3: 'Privada'
    })
enem_2021_df.head()
# Out:
#    NU_ANO     TP_FAIXA_ETARIA TP_SEXO TP_COR_RACA  TP_ST_CONCLUSAO  \
# 1    2021  entre 31 e 35 anos       M      Branca                1
# 3    2021             18 anos       M       Parda                2
# 4    2021             17 anos       F       Parda                2
# 8    2021             23 anos       F       Parda                2
# 9    2021             19 anos       F       Parda                2
#
#        TP_ESCOLA  CO_MUNICIPIO_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 1  Não Respondeu               NaN                     NaN
# 3        Pública         2304202.0                     2.0
# 4        Pública         2311603.0                     2.0
# 8        Pública               NaN                     NaN
# 9        Pública               NaN                     NaN
#
#    TP_LOCALIZACAO_ESC  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  \
# 1                 NaN       505.9       551.8       498.3       461.5
# ...

# %%
enem_2021_df['TP_DEPENDENCIA_ADM_ESC'] = enem_2021_df['TP_DEPENDENCIA_ADM_ESC'].map({ 1: 'Federal',2:'Estadual',3:'Municipal',4:'Privada'})

# %%
enem_2021_df['TP_LOCALIZACAO_ESC'] = enem_2021_df['TP_LOCALIZACAO_ESC'].map({1:'Urbana',2:'Rural'})

# %%
enem_2021_df.drop(columns=['CO_MUNICIPIO_ESC', 'Q022', 'Q024', 'TP_ST_CONCLUSAO'], inplace=True)

# %%
enem_2021_df.head()
# Out:
#    NU_ANO     TP_FAIXA_ETARIA TP_SEXO TP_COR_RACA      TP_ESCOLA  \
# 1    2021  entre 31 e 35 anos       M      Branca  Não Respondeu
# 3    2021             18 anos       M       Parda        Pública
# 4    2021             17 anos       F       Parda        Pública
# 8    2021             23 anos       F       Parda        Pública
# 9    2021             19 anos       F       Parda        Pública
#
#   TP_DEPENDENCIA_ADM_ESC TP_LOCALIZACAO_ESC  NU_NOTA_CN  NU_NOTA_CH  \
# 1                    NaN                NaN       505.9       551.8
# 3               Estadual             Urbana       580.7       678.9
# 4               Estadual             Urbana       497.7       532.4
# 8                    NaN                NaN       487.4       476.5
# 9                    NaN                NaN       507.6       539.2
#
#    NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO              Q001  \
# 1       498.3       461.5            560.0  Não completou EF
# ...

# %%
enem_2021_df['TP_SEXO'] = enem_2021_df['TP_SEXO'].map({'F':'Feminino','M':'Masculino'})

# %%
enem_2021_df.shape
# Out:
# (9935, 18)

# %%
enem_2021_df.to_csv('enem_2021_tratado.csv', index=False)

# %%
enem_2021_df.head()
# Out:
#    NU_ANO     TP_FAIXA_ETARIA    TP_SEXO TP_COR_RACA      TP_ESCOLA  \
# 1    2021  entre 31 e 35 anos  Masculino      Branca  Não Respondeu
# 3    2021             18 anos  Masculino       Parda        Pública
# 4    2021             17 anos   Feminino       Parda        Pública
# 8    2021             23 anos   Feminino       Parda        Pública
# 9    2021             19 anos   Feminino       Parda        Pública
#
#   TP_DEPENDENCIA_ADM_ESC TP_LOCALIZACAO_ESC  NU_NOTA_CN  NU_NOTA_CH  \
# 1                    NaN                NaN       505.9       551.8
# 3               Estadual             Urbana       580.7       678.9
# 4               Estadual             Urbana       497.7       532.4
# 8                    NaN                NaN       487.4       476.5
# 9                    NaN                NaN       507.6       539.2
#
#    NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO              Q001  \
# 1       498.3       461.5            560.0  Não completou EF
# ...
